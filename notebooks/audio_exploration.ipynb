# %% [markdown]
# Importing Libraries

# %%
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Loading Example audio

# %%
audio_path = librosa.ex("trumpet")

y, sr = librosa.load(audio_path)

print("Audio length:", len(y))
print("Sample rate:", sr)
# Out:
# ...
# Audio length: 117601
# Sample rate: 22050

# %% [markdown]
# This loads a built-in sample from librosa

# %%
plt.figure(figsize=(12,4))
librosa.display.waveshow(y, sr=sr)

plt.title("Audio Waveform")
plt.show()

# %% [markdown]
# The above figure shows how audio signals changes overtime.

# %%
#creating a spectrogram

S = librosa.stft(y)
S_db = librosa.amplitude_to_db(abs(S))

plt.figure(figsize=(12,4))
librosa.display.specshow(S_db, sr=sr, x_axis='time', y_axis='log')

plt.colorbar()
plt.title("Spectrogram")
plt.show()

# %% [markdown]
# Spectrogram = time vs frequency representation of sound.

# %%
#Extacting MFCCs features
mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)

print("MFCC shape:", mfcc.shape)
# Out:
# MFCC shape: (13, 230)

# %% [markdown]
# MFCC captures important characteristics of sound

# %%
# Visualizaing MFCCs
plt.figure(figsize=(12,4))
librosa.display.specshow(mfcc, x_axis="time")

plt.colorbar()
plt.title("MFCC Features")
plt.show()

# %%
np.save("../data/features/mfcc_sample.npy", mfcc)
